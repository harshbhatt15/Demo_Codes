# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import Perceptron
import seaborn as sns

# %%
df = pd.read_csv(r'D:\DEMO_CODES\Perceptron\placement.csv')

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.shape
# Out:
# (100, 3)

# %%
#scatter plot
plt.scatter(df['cgpa'],df['resume_score'],c=df['placed'],cmap='bwr')

# %% [markdown]
# blue - not placed
#
# red - placed

# %%
x = df[['cgpa','resume_score']]
y = df['placed']

# %%
p = Perceptron()
p.fit(x,y)
# Out:
# Perceptron()

# %% [markdown]
# #### The formula will be
#
# `z = w1x1 + w2x2 + b`

# %%
p.coef_
# Out:
# array([[ 40.26, -36.  ]])

# %% [markdown]
# `here w1 = 40.26`
#
# `w2 = -36. something`

# %%
p.intercept_
# Out:
# array([-25.])

# %% [markdown]
# `b = 25. something`

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.values, y.values, clf=p, legend=2)
# Out:
# c:\Users\hb292\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
